# %%
years = [1,2,3,4,5,6,7]
salary = [25,30,35,40,45,50,55]

# %%
# y = mx+c

# %%
x = 9
m = 5
c = 20

# %%
m*x+c
# Out:
# 65

# %%
# !pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# X/Input should be 2D, Y/output should be 1D

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = {
    'Years':years,
    'Salary':salary
})

# %%
df
# Out:
#    Years  Salary
# 0      1      25
# 1      2      30
# 2      3      35
# 3      4      40
# 4      5      45
# 5      6      50
# 6      7      55

# %%
model.fit(df.drop(columns=[ 'Salary']), df['Salary'] )
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([5.])

# %%
model.intercept_
# Out:
# np.float64(20.000000000000004)

# %%
model.predict([[9]])
# Out:
# C:\Users\ROYAL WALA\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65.])

# %%
df = pd.read_excel(r"F:\Machine Learning\Machine_Learning\DataModel\Financial_Sample.xlsx")

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(111)

# %%
df.isnull().sum()
# Out:
# Segment                 8
# Country                11
# Product                 8
# Discount Band          62
# Units Sold              5
# Manufacturing Price     0
# Sale Price              7
# Gross Sales             5
# Discounts               5
#  Sales                  0
# COGS                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64

# %%
df = df.bfill()

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# dtype: int64

# %%
df.head(2)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           Low      1618.5
# 1  Government  Germany  Carretera           Low      1321.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3        20.0      32370.0        0.0  32370.0  16185.0
# 1                    3        20.0      26420.0        0.0  26420.0  13210.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014

# %%
df.Segment.unique()
# Out:
# <ArrowStringArray>
# ['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#  'Small Business']
# Length: 5, dtype: str

# %%
df.Segment =df.Segment.map(lambda val:list(df.Segment.unique()).index(val))

# %%
df.head()
# Out:
#    Segment  Country    Product Discount Band  Units Sold  Manufacturing Price  \
# 0        0   Canada  Carretera           Low      1618.5                    3
# 1        0  Germany  Carretera           Low      1321.0                    3
# 2        1   France  Carretera           Low      2178.0                    3
# 3        1  Germany  Carretera           Low       888.0                    3
# 4        1   Mexico  Carretera           Low      2470.0                    3
#
#    Sale Price  Gross Sales  Discounts    Sales     COGS   Profit       Date  \
# 0        20.0      32370.0        0.0  32370.0  16185.0  16185.0 2014-01-01
# 1        20.0      26420.0        0.0  26420.0  13210.0  13210.0 2014-01-01
# 2        15.0      32670.0        0.0  32670.0  21780.0  10890.0 2014-06-01
# 3        15.0      13320.0        0.0  13320.0   8880.0   4440.0 2014-06-01
# 4        15.0      37050.0        0.0  37050.0  24700.0  12350.0 2014-06-01
#
#    Month Number Month Name  Year
# ...

# %%
df.Segment.unique()
# Out:
# array([0, 1, 2, 3, 4])
